# %% [markdown]
# # 1 Retrieving data and storing at WandB
#
# The selected dataset includes 10000+ samples of URL. The data set is balanced, containg exactly 50% of phishing and 50% of legitimate URL.
#
# These Python Notebbok's were developed to proper work on Google Colab.

# %% [markdown]
# ## 1.1 Retrieving Data
#
# The data is available at [kaggle](https://www.kaggle.com/datasets/shashwatwork/web-page-phishing-detection-dataset?resource=download), and also at [data/dataset_phishing.csv](https://github.com/lupamedeiros/phishing-detection/raw/main/data/dataset_phishing.csv).
#
# We are going to read the file and store it at the WandB server.

# %% [markdown]
# ### 1.1.1 Install and Import libraries

# %%
# !pip install pandas
# !pip install wandb
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 1.8 MB 9.3 MB/s
# ...
#      |████████████████████████████████| 147 kB 61.3 MB/s
# ...
#      |████████████████████████████████| 181 kB 40.6 MB/s
# ...
#      |████████████████████████████████| 63 kB 1.9 MB/s
# ...
#   Created wheel for pathtools: filename=pathtools-0.1.2-py3-none-any.whl size=8806 sha256=d4b044837bf87e9d10b5190c6103aa2987dd6279ffb74be5bc67cba340e04560
#   Stored in directory: /root/.cache/pip/wheels/3e/31/09/fa59cef12cdcfecc627b3d24273699f390e71828921b2cbba2
# Successfully built pathtools
# ...

# %%
import wandb
import pandas as pd

# %% [markdown]
# ### 1.1.2 Reading data

# %%
raw_data = pd.read_csv("https://github.com/lupamedeiros/phishing-detection-2/raw/main/data/dataset_phishing.csv")
raw_data.head()
# Out:
#                                                  url  length_url  \
# 0              http://www.crestonwood.com/router.php          37
# 1  http://shadetreetechnology.com/V4/validation/a...          77
# 2  https://support-appleld.com.secureupdate.duila...         126
# 3                                 http://rgipt.ac.in          18
# 4  http://www.iracing.com/tracks/gateway-motorspo...          55
#
#    length_hostname  ip  nb_dots  nb_hyphens  nb_at  nb_qm  nb_and  nb_or  ...  \
# 0               19   0        3           0      0      0       0      0  ...
# 1               23   1        1           0      0      0       0      0  ...
# 2               50   1        4           1      0      1       2      0  ...
# 3               11   0        2           0      0      0       0      0  ...
# 4               15   0        2           2      0      0       0      0  ...
#
#    domain_in_title  domain_with_copyright  whois_registered_domain  \
# ...

# %%
raw_data.to_csv("raw_data.csv", index=False)

# %% [markdown]
# Using a shell run the following commands to (login to wandb, upload the file, remove the file from local disk):
#
#     wandb login --relogin
#     wandb artifact put \
#         --name phishing-detection-2/raw_data.csv \
#         --type data \
#         --description "The supplyed data set" source/creating_model/raw_data.csv
#     rm source/creating_model/raw_data.csv

# %%
# !wandb login --relogin
# !wandb artifact put \
  --name phishing-detection-2/raw_data.csv \
  --type data \
  --description "The supplyed dataset." \
  raw_data.csv
# Out:
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Uploading file raw_data.csv to: "lupamedeiros/phishing-detection-2/raw_data.csv:latest" (data)
# wandb: Currently logged in as: lupamedeiros. Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.12.21
# wandb: Run data is saved locally in /content/wandb/run-20220715_162443-j8vjzrbc
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run serene-river-1
# wandb: ⭐️ View project at https://wandb.ai/lupamedeiros/phishing-detection-2
# wandb: 🚀 View run at https://wandb.ai/lupamedeiros/phishing-detection-2/runs/j8vjzrbc
# Artifact uploaded, use this artifact in a run by adding:
#
# ...
